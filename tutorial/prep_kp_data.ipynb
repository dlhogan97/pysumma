# %%
import xarray as xr

# %%
ds = xr.open_dataset('/home/dlhogan/GitHub/Synoptic-Sublimation/01_data/processed_data/sos_ds_1H_storage.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 4848)
# Coordinates:
#   * time             (time) datetime64[ns] 2022-11-30 ... 2023-06-19T23:00:00
# Data variables: (12/502)
#     counts_1m_c      (time) float64 ...
#     counts_1m_c_1    (time) float64 ...
#     counts_1m_c_2    (time) float64 ...
#     counts_2m_c      (time) float64 ...
#     counts_2m_c_1    (time) float64 ...
#     counts_2m_c_2    (time) float64 ...
#     ...               ...
#     u_tc__20m_c      (time) float64 ...
#     v_tc__20m_c      (time) float64 ...
#     u_h2o__20m_c     (time) float64 ...
#     v_h2o__20m_c     (time) float64 ...
#     w_tc__20m_c      (time) float64 ...
#     w_h2o__20m_c     (time) float64 ...
# Attributes:
#     project:                   SOS
#     history:                   Created: 2024-03-04 08:06:41 +0000\n
#     NIDAS_version:             v1.2.3
#     calibration_file_path:     /h/eol/isfs/isfs/projects/SOS/ISFS/cal_files/$...
# ...

# %%
current_forcing_ds = xr.open_dataset('./data/kettleponds/data/tilden_1hr_2022-2023.nc')
current_forcing_ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 5520, hru: 1)
# Coordinates:
#   * time        (time) datetime64[ns] 2022-11-01 ... 2023-06-18T23:00:00
# Dimensions without coordinates: hru
# Data variables:
#     airpres     (time, hru) float64 ...
#     airtemp     (time, hru) float64 ...
#     windspd     (time, hru) float64 ...
#     SWRadAtm    (time, hru) float64 ...
#     LWRadAtm    (time, hru) float64 ...
#     pptrate     (time, hru) float64 ...
#     spechum     (time, hru) float64 ...
#     gap_filled  (time, hru) float64 ...
#     data_step   float64 ...
#     hruId       (hru) float64 ...
