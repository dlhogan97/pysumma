# %% [markdown]
# # Install SUMMA model configurations
#
# This notebook contains a couple of functions to install SUMMA model configurations that you can then further explore yourself. These model configurations are:
#
# * _SUMMA CUES site_: A SUMMA configuration for the CUES site, which has a lot of snow observations available [_[Bair et al., 2017](https://doi.org/10.3389/feart.2015.00058)_].
#
#     To install the SUMMA setup for the CUES, execute `install_summa_cues_site()` in a code cell at the end of this notebook. The SUMMA configuration will be installed in the directory: `/home/jovyan/data/cues`
#
# * _SUMMA Umpqua site_: This is a SUMMA setup for two locations in the Umpqua watershed in coastal Oregon. The setup is best used for snow modeling and uses data collected by Pascal Storck to investigate snow interception by vegetation in maritime climates [_[Storck et al., 2002](https://doi.org/10.1029/2002WR001281)_].
#
#     To install the SUMMA setup for the Umpqua, execute `install_summa_umpqua_site()` in a code cell at the end of this notebook. The SUMMA configuration will be installed in the directory: `/home/jovyan/data/umpqua`
#
#
# Of course, after you type the code, you will need to run the cell as well. You can browse the directory structure for each of the model configurations in the built-in file manager to the left.

# %%
import subprocess
import tarfile
import glob
import os
import re

cues_source         = 'https://www.dropbox.com/s/b9kckn9qrpzguc5/cues.tar.gz?dl=1'
umpqua_source       = 'https://www.dropbox.com/s/nk0t1qjl8iub722/umpqua.tar.gz?dl=1'

def get_untar(source, destination, remove=True):

    # download the tar file
    tarfilename = '{}/download.tar.gz'.format(destination)
    command = 'wget --max-redirect=20 -O {} {}'.format(tarfilename, source)
    subprocess.run(command.split())
    
    # unpack the tar file
    tar = tarfile.open(tarfilename, 'r:gz')
    tar.extractall(destination)
    
    if remove:
        # remove the tar file
        os.unlink(tarfilename)
    

def install_summa_cues_site(destination='./data/'):
    
    # get tar file and unpack
    get_untar(cues_source, destination)

    # fix the path in the file manager(s)
    ifiles = glob.glob('{}/**/*file_manager*.txt'.format(destination), recursive=True)
    for ifile in ifiles:
        with open(ifile, "r") as f:
            content = f.readlines()
        with open(ifile, "w") as f:
            for line in content:
                f.write(re.sub('./cues', '{}/cues'.format(destination), line))
    
    # Print message
    print('cues installed in {}'.format(destination))

def install_summa_umpqua_site(destination='./data/'):

    # get tar file and unpack
    get_untar(umpqua_source, destination)

    # fix the path in the file manager(s)
    ifiles = glob.glob('{}/**/umpqua/**/*fileManager*.txt'.format(destination), recursive=True)
    for ifile in ifiles:
        with open(ifile, "r") as f:
            content = f.readlines()
        with open(ifile, "w") as f:
            for line in content:
                f.write(re.sub('./umpqua', '{}/umpqua'.format(destination), line))
                
    # Print message
    print('umpqua installed in {}'.format(destination))

# %%
# To install the SUMMA configurations for the CUES site execute the following command:
install_summa_cues_site()
# Out:
# --2024-05-16 12:16:25--  https://www.dropbox.com/s/b9kckn9qrpzguc5/cues.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/b9kckn9qrpzguc5/cues.tar.gz [following]
# --2024-05-16 12:16:26--  https://www.dropbox.com/s/dl/b9kckn9qrpzguc5/cues.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc836351bf9d5ee27610c7c0523e.dl.dropboxusercontent.com/cd/0/get/CTA7-OKfX_yaUPrQrwoUUYI57dhIE_ztp-fqWg7Rp-mXoFoZYT6LTBkdmUR2APBWNYXs2qM0IflKGn8BlsvflDRiKR9sN0Qx2QWfV7B4zfs2vN1CdoH9_1NArlTgo3ApPzmQmnmZIc5c6RcI60ejOLFR/file?dl=1# [following]
# --2024-05-16 12:16:26--  https://uc836351bf9d5ee27610c7c0523e.dl.dropboxusercontent.com/cd/0/get/CTA7-OKfX_yaUPrQrwoUUYI57dhIE_ztp-fqWg7Rp-mXoFoZYT6LTBkdmUR2APBWNYXs2qM0IflKGn8BlsvflDRiKR9sN0Qx2QWfV7B4zfs2vN1CdoH9_1NArlTgo3ApPzmQmnmZIc5c6RcI60ejOLFR/file?dl=1
# Resolving uc836351bf9d5ee27610c7c0523e.dl.dropboxusercontent.com (uc836351bf9d5ee27610c7c0523e.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc836351bf9d5ee27610c7c0523e.dl.dropboxusercontent.com (uc836351bf9d5ee27610c7c0523e.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6956828 (6.6M) [application/binary]
# Saving to: ‘./data//download.tar.gz’
#
#      0K .......... .......... .......... .......... ..........  0% 35.6M 0s
#     50K .......... .......... .......... .......... ..........  1% 49.3M 0s
#    100K .......... .......... .......... .......... ..........  2% 43.5M 0s
#    150K .......... .......... .......... .......... ..........  2% 75.6M 0s
#    200K .......... .......... .......... .......... ..........  3% 62.1M 0s
#    250K .......... .......... .......... .......... ..........  4% 46.0M 0s
#    300K .......... .......... .......... .......... ..........  5% 48.3M 0s
#    350K .......... .......... .......... .......... ..........  5% 43.9M 0s
#    400K .......... .......... .......... .......... ..........  6% 39.8M 0s
#    450K .......... .......... .......... .......... ..........  7% 46.2M 0s
#    500K .......... .......... .......... .......... ..........  8% 45.9M 0s
#    550K .......... .......... .......... .......... ..........  8% 58.5M 0s
#    600K .......... .......... .......... .......... ..........  9% 47.6M 0s
#    650K .......... .......... .......... .......... .......... 10% 58.9M 0s
#    700K .......... .......... .......... .......... .......... 11% 52.5M 0s
#    750K .......... .......... .......... .......... .......... 11% 57.5M 0s
#    800K .......... .......... .......... .......... .......... 12% 49.8M 0s
#    850K .......... .......... .......... .......... .......... 13% 63.8M 0s
#    900K .......... .......... .......... .......... .......... 13% 56.7M 0s
#    950K .......... .......... .......... .......... .......... 14% 46.1M 0s
#   1000K .......... .......... .......... .......... .......... 15% 56.4M 0s
#   1050K .......... .......... .......... .......... .......... 16% 54.7M 0s
#   1100K .......... .......... .......... .......... .......... 16% 59.9M 0s
#   1150K .......... .......... .......... .......... .......... 17% 47.3M 0s
#   1200K .......... .......... .......... .......... .......... 18% 55.5M 0s
#   1250K .......... .......... .......... .......... .......... 19% 58.5M 0s
#   1300K .......... .......... .......... .......... .......... 19% 62.0M 0s
#   1350K .......... .......... .......... .......... .......... 20% 59.9M 0s
#   1400K .......... .......... .......... .......... .......... 21% 57.4M 0s
#   1450K .......... .......... .......... .......... .......... 22% 56.6M 0s
#   1500K .......... .......... .......... .......... .......... 22% 70.4M 0s
#   1550K .......... .......... .......... .......... .......... 23% 60.6M 0s
#   1600K .......... .......... .......... .......... .......... 24% 53.2M 0s
#   1650K .......... .......... .......... .......... .......... 25% 64.6M 0s
#   1700K .......... .......... .......... .......... .......... 25% 60.1M 0s
#   1750K .......... .......... .......... .......... .......... 26% 63.7M 0s
#   1800K .......... .......... .......... .......... .......... 27% 57.3M 0s
#   1850K .......... .......... .......... .......... .......... 27% 74.7M 0s
#   1900K .......... .......... .......... .......... .......... 28% 57.0M 0s
#   1950K .......... .......... .......... .......... .......... 29% 72.7M 0s
#   2000K .......... .......... .......... .......... .......... 30% 52.9M 0s
#   2050K .......... .......... .......... .......... .......... 30% 63.7M 0s
#   2100K .......... .......... .......... .......... .......... 31% 67.6M 0s
#   2150K .......... .......... .......... .......... .......... 32% 90.1M 0s
#   2200K .......... .......... .......... .......... .......... 33%  117M 0s
#   2250K .......... .......... .......... .......... .......... 33%  124M 0s
#   2300K .......... .......... .......... .......... .......... 34%  140M 0s
#   2350K .......... .......... .......... .......... .......... 35%  123M 0s
#   2400K .......... .......... .......... .......... .......... 36%  101M 0s
#   2450K .......... .......... .......... .......... .......... 36%  122M 0s
#   2500K .......... .......... .......... .......... .......... 37%  113M 0s
#   2550K .......... .......... .......... .......... .......... 38%  121M 0s
#   2600K .......... .......... .......... .......... .......... 39%  118M 0s
#   2650K .......... .......... .......... .......... .......... 39%  135M 0s
#   2700K .......... .......... .......... .......... .......... 40%  140M 0s
#   2750K .......... .......... .......... .......... .......... 41%  132M 0s
#   2800K .......... .......... .......... .......... .......... 41%  119M 0s
#   2850K .......... .......... .......... .......... .......... 42%  138M 0s
#   2900K .......... .......... .......... .......... .......... 43%  146M 0s
#   2950K .......... .......... .......... .......... .......... 44%  139M 0s
#   3000K .......... .......... .......... .......... .......... 44%  123M 0s
#   3050K .......... .......... .......... .......... .......... 45%  136M 0s
#   3100K .......... .......... .......... .......... .......... 46%  137M 0s
#   3150K .......... .......... .......... .......... .......... 47%  141M 0s
#   3200K .......... .......... .......... .......... .......... 47%  118M 0s
#   3250K .......... .......... .......... .......... .......... 48%  137M 0s
#   3300K .......... .......... .......... .......... .......... 49%  134M 0s
#   3350K .......... .......... .......... .......... .......... 50%  137M 0s
#   3400K .......... .......... .......... .......... .......... 50%  125M 0s
#   3450K .......... .......... .......... .......... .......... 51%  144M 0s
#   3500K .......... .......... .......... .......... .......... 52%  141M 0s
#   3550K .......... .......... .......... .......... .......... 52%  138M 0s
#   3600K .......... .......... .......... .......... .......... 53%  114M 0s
#   3650K .......... .......... .......... .......... .......... 54%  143M 0s
#   3700K .......... .......... .......... .......... .......... 55%  135M 0s
#   3750K .......... .......... .......... .......... .......... 55%  140M 0s
#   3800K .......... .......... .......... .......... .......... 56%  128M 0s
#   3850K .......... .......... .......... .......... .......... 57%  136M 0s
#   3900K .......... .......... .......... .......... .......... 58%  149M 0s
#   3950K .......... .......... .......... .......... .......... 58%  113M 0s
#   4000K .......... .......... .......... .......... .......... 59% 98.5M 0s
#   4050K .......... .......... .......... .......... .......... 60%  102M 0s
#   4100K .......... .......... .......... .......... .......... 61%  127M 0s
#   4150K .......... .......... .......... .......... .......... 61%  123M 0s
#   4200K .......... .......... .......... .......... .......... 62%  115M 0s
#   4250K .......... .......... .......... .......... .......... 63%  129M 0s
#   4300K .......... .......... .......... .......... .......... 64%  106M 0s
#   4350K .......... .......... .......... .......... .......... 64%  102M 0s
#   4400K .......... .......... .......... .......... .......... 65%  110M 0s
#   4450K .......... .......... .......... .......... .......... 66%  101M 0s
#   4500K .......... .......... .......... .......... .......... 66%  129M 0s
#   4550K .......... .......... .......... .......... .......... 67%  118M 0s
#   4600K .......... .......... .......... .......... .......... 68%  100M 0s
#   4650K .......... .......... .......... .......... .......... 69%  131M 0s
#   4700K .......... .......... .......... .......... .......... 69% 99.8M 0s
#   4750K .......... .......... .......... .......... .......... 70%  126M 0s
#   4800K .......... .......... .......... .......... .......... 71% 91.3M 0s
#   4850K .......... .......... .......... .......... .......... 72%  125M 0s
#   4900K .......... .......... .......... .......... .......... 72%  120M 0s
#   4950K .......... .......... .......... .......... .......... 73%  133M 0s
#   5000K .......... .......... .......... .......... .......... 74% 96.3M 0s
#   5050K .......... .......... .......... .......... .......... 75%  102M 0s
#   5100K .......... .......... .......... .......... .......... 75%  123M 0s
#   5150K .......... .......... .......... .......... .......... 76%  131M 0s
#   5200K .......... .......... .......... .......... .......... 77% 90.6M 0s
#   5250K .......... .......... .......... .......... .......... 78%  123M 0s
#   5300K .......... .......... .......... .......... .......... 78%  130M 0s
#   5350K .......... .......... .......... .......... .......... 79%  102M 0s
#   5400K .......... .......... .......... .......... .......... 80% 95.0M 0s
#   5450K .......... .......... .......... .......... .......... 80%  124M 0s
#   5500K .......... .......... .......... .......... .......... 81%  127M 0s
#   5550K .......... .......... .......... .......... .......... 82%  128M 0s
#   5600K .......... .......... .......... .......... .......... 83% 88.1M 0s
#   5650K .......... .......... .......... .......... .......... 83%  134M 0s
#   5700K .......... .......... .......... .......... .......... 84%  102M 0s
#   5750K .......... .......... .......... .......... .......... 85%  127M 0s
#   5800K .......... .......... .......... .......... .......... 86% 92.7M 0s
#   5850K .......... .......... .......... .......... .......... 86%  131M 0s
#   5900K .......... .......... .......... .......... .......... 87%  124M 0s
#   5950K .......... .......... .......... .......... .......... 88%  104M 0s
#   6000K .......... .......... .......... .......... .......... 89%  109M 0s
#   6050K .......... .......... .......... .......... .......... 89%  104M 0s
#   6100K .......... .......... .......... .......... .......... 90%  100M 0s
#   6150K .......... .......... .......... .......... .......... 91%  129M 0s
#   6200K .......... .......... .......... .......... .......... 91%  116M 0s
#   6250K .......... .......... .......... .......... .......... 92%  127M 0s
#   6300K .......... .......... .......... .......... .......... 93%  124M 0s
#   6350K .......... .......... .......... .......... .......... 94%  110M 0s
#   6400K .......... .......... .......... .......... .......... 94% 89.8M 0s
#   6450K .......... .......... .......... .......... .......... 95%  122M 0s
#   6500K .......... .......... .......... .......... .......... 96%  101M 0s
#   6550K .......... .......... .......... .......... .......... 97%  128M 0s
#   6600K .......... .......... .......... .......... .......... 97%  118M 0s
#   6650K .......... .......... .......... .......... .......... 98%  126M 0s
#   6700K .......... .......... .......... .......... .......... 99%  104M 0s
#   6750K .......... .......... .......... .......... ...       100%  108M=0.08s
#
# 2024-05-16 12:16:27 (86.3 MB/s) - ‘./data//download.tar.gz’ saved [6956828/6956828]
# cues installed in ./data/

# %%
# To install the SUMMA configurations for the Umpqua site execute the following command:
install_summa_umpqua_site()
# Out:
# --2024-05-16 12:16:30--  https://www.dropbox.com/s/nk0t1qjl8iub722/umpqua.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/nk0t1qjl8iub722/umpqua.tar.gz [following]
# --2024-05-16 12:16:30--  https://www.dropbox.com/s/dl/nk0t1qjl8iub722/umpqua.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc559ce7eaebcca55d93cc99286a.dl.dropboxusercontent.com/cd/0/get/CTBwtCupFtwOQ2KDl_7VBhnDtRvxhZSom72_AJBtTDmrKgdHFg2kAJchSVgW5PPXxd5HBHpfFWkv_pAvC8YxGVbsJ3X_aRji16zgbfHAHRWYpT0qmllzdIhKeHOh62gBhPCW7tVyMO6_k9QzE949BcoS/file?dl=1# [following]
# --2024-05-16 12:16:30--  https://uc559ce7eaebcca55d93cc99286a.dl.dropboxusercontent.com/cd/0/get/CTBwtCupFtwOQ2KDl_7VBhnDtRvxhZSom72_AJBtTDmrKgdHFg2kAJchSVgW5PPXxd5HBHpfFWkv_pAvC8YxGVbsJ3X_aRji16zgbfHAHRWYpT0qmllzdIhKeHOh62gBhPCW7tVyMO6_k9QzE949BcoS/file?dl=1
# Resolving uc559ce7eaebcca55d93cc99286a.dl.dropboxusercontent.com (uc559ce7eaebcca55d93cc99286a.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc559ce7eaebcca55d93cc99286a.dl.dropboxusercontent.com (uc559ce7eaebcca55d93cc99286a.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response...
# umpqua installed in ./data/
# 200 OK
# Length: 461332 (451K) [application/binary]
# Saving to: ‘./data//download.tar.gz’
#
#      0K .......... .......... .......... .......... .......... 11% 20.6M 0s
#     50K .......... .......... .......... .......... .......... 22% 63.0M 0s
#    100K .......... .......... .......... .......... .......... 33% 80.0M 0s
#    150K .......... .......... .......... .......... .......... 44% 91.5M 0s
#    200K .......... .......... .......... .......... .......... 55% 82.4M 0s
#    250K .......... .......... .......... .......... .......... 66% 87.5M 0s
#    300K .......... .......... .......... .......... .......... 77% 99.2M 0s
#    350K .......... .......... .......... .......... .......... 88% 88.8M 0s
#    400K .......... .......... .......... .......... .......... 99%  110M 0s
#    450K                                                       100%  991G=0.007s
#
# 2024-05-16 12:16:31 (63.5 MB/s) - ‘./data//download.tar.gz’ saved [461332/461332]
